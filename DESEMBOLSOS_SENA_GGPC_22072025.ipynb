# %% [markdown]
# <a href="https://colab.research.google.com/github/richbello/sena_ggpc/blob/main/DESEMBOLSOS_SENA_GGPC_22072025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd

# Subir el archivo
uploaded = files.upload()

# Cargar el Excel (usa el nombre exacto del archivo que subiste)
df = pd.read_excel(next(iter(uploaded)))

# Mostrar las primeras filas
print(df.head())
# Out:
#      <input type="file" id="files-ccc069e1-d878-4931-82c9-e129672bb882" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ccc069e1-d878-4931-82c9-e129672bb882">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Crear el DataFrame con los datos correctos desde la imagen
data = {
    "PROPONENTE": [
        "ASOCIACION COLOMBIANA DE COOPERATIVAS - ASCOOP",
        "ASOCIACIÓN PARA EL FOMENTO DE LA INNOVACIÓN Y DESARROLLO DE LOS GREMIOS - AFIDG",
        "CAMARA COLOMBIANA DE COMERCIO ELECTRONICO",
        "CÁMARA COLOMBIANA DE LA CONSTRUCCIÓN - CAMACOL",
        "CÁMARA DE COMERCIO DE BUCARAMANGA",
        "CÁMARA DE COMERCIO DE CÚCUTA",
        "FONDO DE DESARROLLO DE LA EDUCACIÓN SUPERIOR-FODESEP",
        "SODIMAC COLOMBIA SA"
    ],
    "EJECUTADO": [
        "99,89%", "99,60%", "99,62%", "91,08%", "94,32%", "99,96%", "99,92%", "99,86%"
    ]
}

# Convertir a DataFrame
df = pd.DataFrame(data)

# Limpiar y convertir los porcentajes a números
df["% Ejecutado"] = df["EJECUTADO"].str.replace(",", ".").str.replace("%", "").astype(float)

# Ordenar por menor ejecución
df = df.sort_values(by="% Ejecutado", ascending=True)

# Graficar
plt.figure(figsize=(12, 6))
sns.barplot(data=df, x="% Ejecutado", y="PROPONENTE", palette="RdYlGn")

# Agregar valores en las barras
for i, (valor, nombre) in enumerate(zip(df["% Ejecutado"], df["PROPONENTE"])):
    plt.text(valor + 0.1, i, f"{valor:.2f}%", va='center')

# Títulos y estética
plt.title("Porcentaje Ejecutado por Proponente", fontsize=14)
plt.xlabel("Porcentaje Ejecutado")
plt.ylabel("Proponente")
plt.xlim(90, 100)
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-21-2604893801.py:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="% Ejecutado", y="PROPONENTE", palette="RdYlGn")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Datos extraídos de la imagen
data = {
    "PROPONENTE": [
        "CÁMARA COLOMBIANA DE LA CONSTRUCCIÓN - CAMACOL",
        "CAMARA COLOMBIANA DE COMERCIO ELECTRONICO",
        "CÁMARA DE COMERCIO DE BUCARAMANGA",
        "ASOCIACIÓN PARA EL FOMENTO DE LA INNOVACIÓN Y DESARROLLO DE LOS GREMIOS - AFIDG",
        "FONDO DE DESARROLLO DE LA EDUCACIÓN SUPERIOR-FODESEP",
        "ASOCIACION COLOMBIANA DE COOPERATIVAS - ASCOOP",
        "SODIMAC COLOMBIA SA",
        "CÁMARA DE COMERCIO E INDUSTRIA FRANCE COLOMBIA",
        "CÁMARA DE COMERCIO DE CÚCUTA",
        "ASOCIACIÓN NACIONAL DE ENTIDADES DE EDUCACIÓN PARA EL TRABAJO Y EL DESARROLLO HUMANO - ASENOF",
        "FEDERACIÓN LATINOAMERICANA DE EMPRESARIOS - FEDELAM",
        "ASOCIACION COLOMBIANA DE CONTACT CENTERS Y BPO – BPRO",
        "BRITISH COLOMBIAN CHAMBER OF COMMERCE",
        "JERONIMO MARTINS COLOMBIA SAS",
        "CAMARA DE COMERCIO DE BUGA",
        "COOPERATIVA NACIONAL DE DROGUISTAS DETALLISTAS - COOPIDROGAS"
    ],
    "RECURSOS NO EJECUTADOS": [
        136691869,
        3661625,
        1959576,
        1075015,
        766385,
        708687,
        170150,
        18196,
        16517,
        8901,
        96,
        3,
        2,
        1,
        1,
        1
    ]
}

# Crear DataFrame
df = pd.DataFrame(data)

# Ordenar por valores de forma descendente
df = df.sort_values(by="RECURSOS NO EJECUTADOS", ascending=False)

# Crear gráfico de barras
plt.figure(figsize=(12, 8))
sns.barplot(x="RECURSOS NO EJECUTADOS", y="PROPONENTE", data=df, palette="Reds_r")

# Agregar etiquetas en las barras
for index, value in enumerate(df["RECURSOS NO EJECUTADOS"]):
    plt.text(value + 50000, index, f"${value:,.0f}", va='center')

# Personalización
plt.title("Recursos No Ejecutados por Proponente", fontsize=14)
plt.xlabel("Monto en Pesos")
plt.ylabel("Proponente")
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-22-3640486164.py:53: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="RECURSOS NO EJECUTADOS", y="PROPONENTE", data=df, palette="Reds_r")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Datos extraídos del archivo proporcionado
data = {
    "NOMBRE DEL PROPONENTE": [
        "ASOCIACIÓN COLOMBIANA DE ACADEMIAS DE SEGURIDAD PRIVADA - ACASEP",
        "ASOCIACIÓN COLOMBIANA DE ATRACCIONES Y PARQUES - ACOLAP",
        "ASOCIACIÓN COLOMBIANA DE CONTACT CENTERS Y BPO – BPRO",
        "ASOCIACIÓN COLOMBIANA DE COOPERATIVAS - ASCOOP",
        "ASOCIACIÓN COLOMBIANA DE EMPRESAS SOCIALES DEL ESTADO Y HOSPITALES PUBLICOS - ACESI",
        "ASOCIACIÓN COLOMBIANA DE INDUSTRIAS PLÁSTICAS - ACOPLÁSTICOS",
        "ASOCIACIÓN COLOMBIANA DE INSTITUCIONES DE EDUCACIÓN SUPERIOR - ACIET",
        "ASOCIACIÓN COLOMBIANA DE LA INDUSTRIA GASTRONÓMICA - ACODRES",
        "ASOCIACIÓN COLOMBIANA PARA EL DESARROLLO EMPRESARIAL - ASOCODEM",
        "ASOCIACIÓN DE EMPRESAS SOCIALES DEL ESTADO DE ANTIOQUIA - AESA",
        "ASOCIACIÓN DE HOSPITALES DEL VALLE DEL CAUCA - ASOHOSVAL",
        "ASOCIACIÓN DEL SECTOR AUTOMOTRIZ - ASOPARTES",
        "ASOCIACIÓN NACIONAL DE COMERCIO EXTERIOR - ANALDEX",
        "ASOCIACIÓN NACIONAL DE EDUCACIÓN PARA EL TRABAJO - ASENOF",
        "ASOCIACIÓN DE GESTIÓN DE PROYECTOS - ASODESING",
        "ASOCIACIÓN PARA LA INNOVACIÓN - AFIDG",
        "ASOCIACIÓN DE COMERCIANTES DE SANTA MARTA - UNDECO",
        "BRITISH COLOMBIAN CHAMBER OF COMMERCE",
        "CÁMARA DE COMERCIO ELECTRÓNICO",
        "CÁMARA COLOMBIANA DE LA CONSTRUCCIÓN - CAMACOL",
        "CÁMARA DE COMERCIO DE BUCARAMANGA",
        "CÁMARA DE COMERCIO DE BUGA",
        "CÁMARA DE COMERCIO DE CÚCUTA",
        "CÁMARA DE COMERCIO DE VALLEDUPAR",
        "CÁMARA DE COMERCIO FRANCE COLOMBIA",
        "CÁMARA DE COMERCIO ALEMANA - AHK",
        "CÁMARA DE COMERCIO DE ESPAÑA - CAMACOES",
        "COASPHARMA SAS",
        "COOPIDROGAS",
        "COSESAM",
        "CORPORACIÓN UNIVERSITARIA AMERICANA",
        "FEDERACIÓN DE MUNICIPIOS - FCM",
        "FEDELAM",
        "FODESEP",
        "JERONIMO MARTINS COLOMBIA",
        "CONACED",
        "SODIMAC COLOMBIA",
        "CAJAS DE COMPENSACIÓN 2024",
        "KERALTY",
        "UNIVERSIDAD ECCI"
    ],
    "VALOR DE CONFINANCIACIÓN": [
        2234173536, 2461000000, 618325673, 626054916, 2483000000, 306585400, 978205300,
        2480000000, 143641722, 2417142000, 1573376400, 1409973300, 2235494600, 905648870,
        2000375500, 271702180, 2011318500, 1250533330, 962850378, 1532637061, 34510000,
        41716320, 42038164, 2467238000, 1636515260, 1557032092, 1729019606, 34346176,
        60793979, 2419766000, 266285800, 1669648600, 2474607280, 996863900, 168177194,
        2483000000, 118600000, 1998798200, 193950460, 389018240
    ],
    "DESEMBOLSO 1": [
        446834707, 492200000, 123665135, 125210983, 496600000, 61317080, 195641060,
        496000000, 28728344, 483428400, 314675280, 281994660, 385519420, 181129774,
        400075100, 54340436, 402263700, 250106666, 192570076, 306527412, 6902000,
        8343264, 8407633, 493447600, 327303052, 311406418, 309912947, 6869235,
        12158796, 483953200, 53257160, 333929720, 494921456, 199372780, 33635439,
        496600000, 23720000, 399759640, 38790092, 77803648
    ],
    "DESEMBOLSO 2": [
        1117086768, 1230500000, 309162837, 313027458, 1241500000, 153292700, 489102650,
        1240000000, 71820861, 1208571000, 786688200, 704986650, 1156234488, 452824435,
        1000187750, 135851090, 1005659259, 625266665, 481425189, 766318531, 17255000,
        20858160, 21019082, 1233619000, 818257630, 778516046, 886941662, 17173088,
        30396990, 1209883000, 133142900, 834824300, 1237303640, 498431950, 84088597,
        1241500000, 59300000, 999399100, 96975230, 194509120
    ],
    "DESEMBOLSO 3": [
        670252061, 738300000, 185497699, 187107788, 744900000, 91975620, 293461590,
        744000000, 43092517, 725142600, 472012920, 422991990, 693740693, 271685760,
        600112650, 80435639, 603395550, 375159997, 285193488, 323099249, 8393424,
        12514895, 12594932, 740171400, 490936382, 467109628, 532164997, 10303853,
        18238193, 725929800, 79885740, 500894580, 742382088, 298292786, 50453157,
        744900000, 35409850, 599639460, 58185138, 116705472
    ]
}

# Crear DataFrame
df = pd.DataFrame(data)

# Calcular recursos no ejecutados
df["RECURSOS NO EJECUTADOS"] = df["VALOR DE CONFINANCIACIÓN"] - (df["DESEMBOLSO 1"] + df["DESEMBOLSO 2"] + df["DESEMBOLSO 3"])

# Ordenar por recursos no ejecutados
df_sorted = df.sort_values(by="RECURSOS NO EJECUTADOS", ascending=False)

# Graficar los recursos no ejecutados
plt.figure(figsize=(12, 14))
sns.set(style="whitegrid")
ax = sns.barplot(x="RECURSOS NO EJECUTADOS", y="NOMBRE DEL PROPONENTE", data=df_sorted, palette="magma")

# Etiquetas con formato de pesos
for i, v in enumerate(df_sorted["RECURSOS NO EJECUTADOS"]):
    ax.text(v + 1000000, i, f"${v:,.0f}", color='black', va='center', fontsize=8)

plt.title("Recursos No Ejecutados por Proponente", fontsize=16, weight='bold')
plt.xlabel("Monto no ejecutado (COP)", fontsize=12)
plt.ylabel("Proponente", fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-23-2539926044.py:95: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x="RECURSOS NO EJECUTADOS", y="NOMBRE DEL PROPONENTE", data=df_sorted, palette="magma")

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Datos procesados manualmente de la imagen (primeros 10 registros para demostración)
data = {
    "Nombre": [
        "ACASEP", "ACOLAP", "BPRO", "ASCOOP", "ACESI",
        "ACOPLASTICOS", "ACIET", "ACODRES", "ASOCODEM", "AESA"
    ],
    "Desembolso 1 (20%)": [
        446834707, 492200000, 123665135, 125210983, 496600000,
        61317080, 195641060, 496000000, 28728344, 483428400
    ],
    "Desembolso 2 (50%)": [
        1117086768, 1230500000, 309162837, 313027458, 1241500000,
        153292700, 489102650, 1240000000, 71820861, 1208571000
    ],
    "Desembolso 3 (30%)": [
        670252061, 738300000, 185497699, 187107788, 744900000,
        91975620, 293461590, 744000000, 43092517, 725142600
    ]
}

# Crear DataFrame
df = pd.DataFrame(data)
df.set_index("Nombre", inplace=True)

# Crear gráfica de barras apiladas
plt.figure(figsize=(14, 8))
df.plot(kind="bar", stacked=True, colormap="viridis", figsize=(14, 8))

plt.title("Distribución de Desembolsos por Proponente (Primeros 10)", fontsize=16)
plt.ylabel("Valor en pesos", fontsize=12)
plt.xlabel("Proponente", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.legend(title="Fase del Desembolso", fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Datos extraídos manualmente del contenido (los primeros 42 proponentes)
data = {
    "NOMBRE DEL PROPONENTE": [
        "ACASEP", "ACOLAP", "ACASEP (rep)", "ACOLAP (rep)", "BPRO", "ASCOOP", "ACESI", "ACOPLASTICOS",
        "ACIET", "ACODRES", "ASOCODEM", "AESA", "ASOHOSVAL", "ASOPARTES", "ANALDEX", "ASENOF",
        "ASODESING", "AFIDG", "UNDECO", "BRITISH COLOMBIAN CHAMBER", "CCE", "CAMACOL",
        "CC BUCARAMANGA", "CC BUGA", "CC CÚCUTA", "CC VALLEDUPAR", "CC FRANCESA", "AHK", "CAMACOES",
        "COASPHARMA", "COOPIDROGAS", "COSESAM", "U. AMERICANA", "FCM", "FEDELAM", "FODESEP",
        "JERONIMO MARTINS", "CONACED", "SODIMAC", "CAJAS 2024", "KERALTY", "ECCI"
    ],
    "VALOR DE COFINANCIACIÓN": [
        2234173536, 2461000000, 2234173536, 2461000000, 618325673, 626054916, 2483000000, 306585400,
        978205300, 2480000000, 143641722, 2417142000, 1573376400, 1409973300, 2235494600, 905648870,
        2000375500, 271702180, 2011318500, 1250533330, 962850378, 1532637061, 34510000, 41716320,
        42038164, 2467238000, 1636515260, 1557032092, 1729019606, 34346176, 60793979, 2419766000,
        266285800, 1669648600, 2474607280, 996863900, 168177194, 2483000000, 118600000, 1998798200,
        193950460, 389018240
    ]
}

df = pd.DataFrame(data)

# Configurar estilo
plt.figure(figsize=(16, 14))
sns.set_style("whitegrid")
bars = sns.barplot(
    y="NOMBRE DEL PROPONENTE",
    x="VALOR DE COFINANCIACIÓN",
    data=df,
    palette="viridis"
)

# Agregar etiquetas dentro de cada barra
for bar in bars.patches:
    bars.text(
        bar.get_width() - (bar.get_width() * 0.15),
        bar.get_y() + bar.get_height() / 2,
        f"${bar.get_width():,.0f}",
        ha='right', va='center', fontsize=8, color='white'
    )

plt.title("Valor de Cofinanciación por Proponente (42 primeros)", fontsize=14)
plt.xlabel("Valor de Cofinanciación")
plt.ylabel("Nombre del Proponente")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2-2432717161.py:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   bars = sns.barplot(
