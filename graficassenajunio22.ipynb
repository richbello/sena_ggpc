# %% [markdown]
# <a href="https://colab.research.google.com/github/richbello/sena_ggpc/blob/main/graficassenajunio22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Nuevos colores armonizados
color_femenino = "#4A90E2"   # Azul claro
color_masculino = "#003f5c"  # Azul oscuro
color_otros = "#a3a3a3"      # Gris suave

# Calcular porcentajes para etiquetas
df["Total"] = df["FEMENINO"] + df["MASCULINO"] + df["OTROS"]
df["FEMENINO_PCT"] = df["FEMENINO"] / df["Total"] * 100
df["MASCULINO_PCT"] = df["MASCULINO"] / df["Total"] * 100
df["OTROS_PCT"] = df["OTROS"] / df["Total"] * 100

# Crear gráfico
plt.figure(figsize=(14, 8))

# Gráfico de barras apiladas con nuevos colores
bar1 = plt.bar(df["Actividad"], df["FEMENINO"], label="Femenino", color=color_femenino)
bar2 = plt.bar(df["Actividad"], df["MASCULINO"], bottom=df["FEMENINO"], label="Masculino", color=color_masculino)
bottom_values = df["FEMENINO"] + df["MASCULINO"]
bar3 = plt.bar(df["Actividad"], df["OTROS"], bottom=bottom_values, label="Otros", color=color_otros)

# Etiquetas de porcentaje
for i in range(len(df)):
    plt.text(i, df["FEMENINO"][i] / 2, f'{df["FEMENINO_PCT"][i]:.1f}%', ha='center', va='center', fontsize=8, color='black')
    plt.text(i, df["FEMENINO"][i] + df["MASCULINO"][i] / 2, f'{df["MASCULINO_PCT"][i]:.1f}%', ha='center', va='center', fontsize=8, color='white')
    if df["OTROS"][i] > 0:
        plt.text(i, bottom_values[i] + df["OTROS"][i] / 2, f'{df["OTROS_PCT"][i]:.1f}%', ha='center', va='center', fontsize=8, color='black')

# Personalización del gráfico
plt.title("Participación por Actividad y Género (con porcentajes)", fontsize=14)
plt.xlabel("Tipo de Evento")
plt.ylabel("Número de Participantes")
plt.xticks(rotation=45, ha='right')
plt.legend(title="Género")
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Crear el DataFrame con los datos generales por género y grupo etario
data = {
    "Grupo Etario": ["<=17", "18-24", "25-30", "31-40", "41-55", ">=56"],
    "FEMENINO": [131, 2374, 4919, 9454, 8469, 1449],
    "MASCULINO": [157, 1893, 3830, 6762, 6619, 1921],
    "OTROS": [10, 9, 40, 71, 47, 12]
}

df = pd.DataFrame(data)
df["Total"] = df["FEMENINO"] + df["MASCULINO"] + df["OTROS"]

# Calcular proporciones para etiquetas
df["FEMENINO_PCT"] = df["FEMENINO"] / df["Total"] * 100
df["MASCULINO_PCT"] = df["MASCULINO"] / df["Total"] * 100
df["OTROS_PCT"] = df["OTROS"] / df["Total"] * 100

# Colores vivos y elegantes
color_femenino = "#FF69B4"   # Rosado fuerte
color_masculino = "#1E90FF"  # Azul vibrante
color_otros = "#32CD32"      # Verde lima

# Crear gráfico de barras apiladas
plt.figure(figsize=(12, 8))
bar1 = plt.bar(df["Grupo Etario"], df["FEMENINO"], label="Femenino", color=color_femenino)
bar2 = plt.bar(df["Grupo Etario"], df["MASCULINO"], bottom=df["FEMENINO"], label="Masculino", color=color_masculino)
bottom_values = df["FEMENINO"] + df["MASCULINO"]
bar3 = plt.bar(df["Grupo Etario"], df["OTROS"], bottom=bottom_values, label="Otros", color=color_otros)

# Agregar etiquetas de porcentaje
for i in range(len(df)):
    plt.text(i, df["FEMENINO"][i] / 2, f'{df["FEMENINO_PCT"][i]:.1f}%', ha='center', va='center', fontsize=8, color='black')
    plt.text(i, df["FEMENINO"][i] + df["MASCULINO"][i] / 2, f'{df["MASCULINO_PCT"][i]:.1f}%', ha='center', va='center', fontsize=8, color='white')
    if df["OTROS"][i] > 0:
        plt.text(i, bottom_values[i] + df["OTROS"][i] / 2, f'{df["OTROS_PCT"][i]:.1f}%', ha='center', va='center', fontsize=8, color='black')

# Personalizar gráfico
plt.title("Distribución por Grupo Etario y Género", fontsize=14)
plt.xlabel("Grupo Etario")
plt.ylabel("Número de Participantes")
plt.legend(title="Género")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Crear el DataFrame con los datos generales por género y grupo etario
data = {
    "Grupo Etario": ["<=17", "18-24", "25-30", "31-40", "41-55", ">=56"],
    "FEMENINO": [131, 2374, 4919, 9454, 8469, 1449],
    "MASCULINO": [157, 1893, 3830, 6762, 6619, 1921],
    "OTROS": [10, 9, 40, 71, 47, 12]
}

df = pd.DataFrame(data)
df["Total"] = df["FEMENINO"] + df["MASCULINO"] + df["OTROS"]

# Calcular proporciones para etiquetas
df["FEMENINO_PCT"] = df["FEMENINO"] / df["Total"] * 100
df["MASCULINO_PCT"] = df["MASCULINO"] / df["Total"] * 100
df["OTROS_PCT"] = df["OTROS"] / df["Total"] * 100

# Colores vivos y elegantes
color_femenino = "#96ceb4"   # Rosado fuerte
color_masculino = "#ffcc5c"  # Azul vibrante
color_otros = "#32CD32"      # Verde lima

# Crear gráfico de barras apiladas
plt.figure(figsize=(12, 8))
bar1 = plt.bar(df["Grupo Etario"], df["FEMENINO"], label="Femenino", color=color_femenino)
bar2 = plt.bar(df["Grupo Etario"], df["MASCULINO"], bottom=df["FEMENINO"], label="Masculino", color=color_masculino)
bottom_values = df["FEMENINO"] + df["MASCULINO"]
bar3 = plt.bar(df["Grupo Etario"], df["OTROS"], bottom=bottom_values, label="Otros", color=color_otros)

# Agregar etiquetas de porcentaje
for i in range(len(df)):
    plt.text(i, df["FEMENINO"][i] / 2, f'{df["FEMENINO_PCT"][i]:.1f}%', ha='center', va='center', fontsize=8, color='black')
    plt.text(i, df["FEMENINO"][i] + df["MASCULINO"][i] / 2, f'{df["MASCULINO_PCT"][i]:.1f}%', ha='center', va='center', fontsize=8, color='white')
    if df["OTROS"][i] > 0:
        plt.text(i, bottom_values[i] + df["OTROS"][i] / 2, f'{df["OTROS_PCT"][i]:.1f}%', ha='center', va='center', fontsize=8, color='black')

# Personalizar gráfico
plt.title("Distribución por Grupo Etario y Género", fontsize=14)
plt.xlabel("Grupo Etario")
plt.ylabel("Número de Participantes")
plt.legend(title="Género")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configurar estilo
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (14, 6)

# Datos resumidos manualmente (valores totales por grupo)
data = {
    'Nivel': ['Alta Dirección'] * 3 + ['Medio'] * 3 + ['Operativo'] * 3,
    'Género': ['Femenino', 'Masculino', 'Otros'] * 3,
    'Total': [4727, 5186, 39, 11513, 8903, 91, 10556, 7093, 59]
}

df = pd.DataFrame(data)

# Crear gráfico de barras apiladas
fig, ax = plt.subplots()
df_pivot = df.pivot(index='Nivel', columns='Género', values='Total')
df_pivot.plot(kind='bar', stacked=True, ax=ax, cmap='Accent')

# Etiquetas y formato
ax.set_title('Distribución por Nivel Ocupacional, Género y Total General', fontsize=14)
ax.set_ylabel('Número de Participantes')
ax.set_xlabel('Nivel Ocupacional')
ax.legend(title='Género')
plt.xticks(rotation=0)
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Datos resumidos a nivel de ejemplo (sintetizado por grupo). Puedes adaptar desde tu fuente original.
data = {
    'Nivel': ['Alta Dirección'] * 6 + ['Medio'] * 6 + ['Operativo'] * 6,
    'Estrato': [1, 2, 3, 4, 5, 6] * 3,
    'Femenino': [410, 1221, 1738, 842, 352, 164,
                 1169, 3087, 4891, 1749, 509, 107,
                 3373, 3461, 2860, 687, 138, 37],
    'Masculino': [447, 1615, 1868, 783, 332, 141,
                  824, 2388, 3977, 1270, 361, 83,
                  1968, 2495, 1970, 532, 103, 25],
    'Otros': [5, 14, 12, 2, 0, 3,
              18, 22, 37, 12, 1, 0,
              18, 19, 15, 6, 0, 1]
}

df = pd.DataFrame(data)

# Reformatear para seaborn (long-form)
df_long = df.melt(id_vars=['Nivel', 'Estrato'], var_name='Género', value_name='Total')

# Crear gráfico de barras apiladas
plt.figure(figsize=(16, 8))
sns.barplot(data=df_long, x='Estrato', y='Total', hue='Género', hue_order=['Femenino', 'Masculino', 'Otros'],
            estimator=sum, ci=None, palette='Set2', dodge=True)

# Añadir etiquetas de valores encima de cada barra
for index, row in df_long.iterrows():
    if row['Total'] > 0:
        plt.text(x=row['Estrato'] - 1 + (0.25 if row['Género'] == 'Femenino' else (0 if row['Género'] == 'Masculino' else -0.25)),
                 y=row['Total'] + 30,
                 s=int(row['Total']),
                 ha='center', va='bottom', fontsize=8)

plt.title('Participación por Nivel, Estrato y Género', fontsize=16)
plt.xlabel('Estrato')
plt.ylabel('Total de Participantes')
plt.legend(title='Género')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-11-616097863.py:27: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df_long, x='Estrato', y='Total', hue='Género', hue_order=['Femenino', 'Masculino', 'Otros'],

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Datos simplificados por Nivel y Estrato
data = {
    'Nivel': ['Alta Dirección'] * 6 + ['Medio'] * 6 + ['Operativo'] * 6,
    'Estrato': [1, 2, 3, 4, 5, 6] * 3,
    'Femenino': [410, 1221, 1738, 842, 352, 164,
                 1169, 3087, 4891, 1749, 509, 107,
                 3373, 3461, 2860, 687, 138, 37],
    'Masculino': [447, 1615, 1868, 783, 332, 141,
                  824, 2388, 3977, 1270, 361, 83,
                  1968, 2495, 1970, 532, 103, 25],
    'Otros': [5, 14, 12, 2, 0, 3,
              18, 22, 37, 12, 1, 0,
              18, 19, 15, 6, 0, 1]
}

# Convertir a DataFrame largo
df = pd.DataFrame(data)
df_long = df.melt(id_vars=['Nivel', 'Estrato'], var_name='Género', value_name='Total')

# Configurar colores elegantes
palette = {
    'Femenino': '#A569BD',  # violeta
    'Masculino': '#3498DB',  # azul
    'Otros': '#F5B041'       # ámbar
}

# Gráfico
plt.figure(figsize=(16, 8))
sns.barplot(
    data=df_long,
    x='Estrato',
    y='Total',
    hue='Género',
    hue_order=['Femenino', 'Masculino', 'Otros'],
    estimator=sum,
    dodge=True,
    errorbar=None,
    palette=palette
)

# Etiquetas encima de cada barra
for index, row in df_long.iterrows():
    if row['Total'] > 0:
        x_pos = row['Estrato'] - 1 + (0.25 if row['Género'] == 'Femenino' else (0 if row['Género'] == 'Masculino' else -0.25))
        plt.text(x=x_pos, y=row['Total'] + 30,
                 s=str(int(row['Total'])), ha='center', va='bottom', fontsize=8)

plt.title('Participación por Estrato, Género y Nivel Ocupacional', fontsize=16)
plt.xlabel('Estrato Socioeconómico')
plt.ylabel('Número de Participantes')
plt.legend(title='Género')
plt.xticks(ticks=range(6), labels=['1', '2', '3', '4', '5', '6'])
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Datos resumidos manualmente de la imagen para ejemplo (se puede cargar de Excel real para análisis completo)
data = {
    "Género": ["Femenino", "Masculino", "Otros"],
    "Alta Dirección": [4727, 5186, 39],
    "Medio": [11513, 8903, 91],
    "Operativo": [10556, 7093, 59],
    "Total": [26796, 21182, 189]
}

df = pd.DataFrame(data)
df.set_index("Género", inplace=True)

# Crear gráfico de barras apiladas
plt.figure(figsize=(10, 6))
colors = ["#008080", "#a39193", "#89ecda"]  # Tonos elegantes de azul

bottom_prev = None
for i, col in enumerate(["Alta Dirección", "Medio", "Operativo"]):
    plt.bar(df.index, df[col], bottom=bottom_prev, label=col, color=colors[i])
    if bottom_prev is None:
        bottom_prev = df[col]
    else:
        bottom_prev += df[col]

# Etiquetas con porcentaje en las barras
totals = df["Total"]
for i, (index, row) in enumerate(df.iterrows()):
    bottom = 0
    for col in ["Alta Dirección", "Medio", "Operativo"]:
        height = row[col]
        percentage = (height / row["Total"]) * 100
        plt.text(i, bottom + height / 2, f"{percentage:.1f}%", ha='center', va='center', color="white", fontsize=9, fontweight="bold")
        bottom += height

# Estética del gráfico
plt.title("Distribución por Género y Nivel Ocupacional", fontsize=14, fontweight='bold')
plt.ylabel("Número de Participantes")
plt.xlabel("Género")
plt.legend(title="Nivel Ocupacional", loc="upper right")
sns.despine()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Estilo profesional
sns.set(style="whitegrid", palette="muted", font_scale=1.2)

# Datos proporcionados
data = {
    "Rango de Edad": [
        "DE 17 AÑOS Y MENOR",
        "DE 18 A 24 AÑOS",
        "DE 25 A 30 AÑOS",
        "DE 31 A 40 AÑOS",
        "DE 41 A 55 AÑOS",
        "DE 56 AÑOS Y MAYOR"
    ],
    "Personas": [
        298,
        4276,
        8789,
        16287,
        15135,
        3382
    ]
}

df = pd.DataFrame(data)

# Crear gráfico de barras
plt.figure(figsize=(12, 6))
colors = sns.color_palette("dark", len(df))
barplot = sns.barplot(x="Rango de Edad", y="Personas", data=df, palette=colors)

# Añadir etiquetas
for index, row in df.iterrows():
    barplot.text(index, row.Personas + 500, f"{row.Personas:,}", color='black', ha="center", fontweight='bold')

# Personalización
plt.title("Distribución de Personas por Rango de Edad (Total Nacional)", fontsize=16, weight='bold')
plt.ylabel("Número de Personas")
plt.xlabel("Rango de Edad")
plt.xticks(rotation=15)
plt.tight_layout()

plt.show()
# Out:
# /tmp/ipython-input-1-697951594.py:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(x="Rango de Edad", y="Personas", data=df, palette=colors)

# %%
# Reimportar bibliotecas después del reinicio del estado
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Estilo profesional
sns.set(style="whitegrid", palette="muted", font_scale=1.2)

# Datos proporcionados
data = {
    "Rango de Edad": [
        "DE 17 AÑOS Y MENOR",
        "DE 18 A 24 AÑOS",
        "DE 25 A 30 AÑOS",
        "DE 31 A 40 AÑOS",
        "DE 41 A 55 AÑOS",
        "DE 56 AÑOS Y MAYOR"
    ],
    "Personas": [
        298,
        4276,
        8789,
        16287,
        15135,
        3382
    ]
}

df = pd.DataFrame(data)

# Crear gráfico de barras
plt.figure(figsize=(12, 6))
colors = sns.color_palette("dark", len(df))
barplot = sns.barplot(x="Rango de Edad", y="Personas", data=df, palette=colors)

# Añadir etiquetas
for index, row in df.iterrows():
    barplot.text(index, row.Personas + 500, f"{row.Personas:,}", color='black', ha="center", fontweight='bold')

# Personalización
plt.title("Distribución de Personas por Rango de Edad (Total Nacional)", fontsize=16, weight='bold')
plt.ylabel("Número de Personas")
plt.xlabel("Rango de Edad")
plt.xticks(rotation=15)
plt.tight_layout()

# Mostrar gráfico
plt.show()
# Out:
# /tmp/ipython-input-2-95217018.py:34: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(x="Rango de Edad", y="Personas", data=df, palette=colors)

# %%
# Crear manualmente el DataFrame desde los datos proporcionados
data = {
    "Departamento": [
        "AMAZONAS", "ANTIOQUIA", "ARAUCA", "ARCHIPIÉLAGO DE SAN", "ATLÁNTICO", "BOGOTÁ D.C", "BOLÍVAR", "BOYACÁ",
        "CALDAS", "CAQUETÁ", "CASANARE", "CAUCA", "CESAR", "CHOCÓ", "CÓRDOBA", "CUNDINAMARCA", "GUAINÍA", "GUAVIARE",
        "HUILA", "LA GUAJIRA", "MAGDALENA", "META", "NARIÑO", "NINGUNO", "NORTE DE SANTANDER", "PUTUMAYO", "QUINDIO",
        "RISARALDA", "SANTANDER", "SUCRE", "TOLIMA", "VALLE DEL CAUCA", "VAUPÉS", "VICHADA", "(en blanco)"
    ],
    "DE 17 AÑOS Y MENOR": [
        0, 19, 3, 0, 9, 81, 1, 4, 1, 1, 4, 3, 13, 1, 4, 44, 0, 0, 3, 1, 3, 8, 0, 11, 6, 0, 14, 8, 16, 1, 12, 27, 0, 0, 0
    ],
    "DE 18 A 24 AÑOS": [
        4, 437, 83, 7, 301, 1046, 92, 77, 67, 14, 39, 36, 484, 22, 48, 272, 0, 2, 75, 29, 138, 42, 76, 6, 101, 2, 57, 78,
        270, 10, 51, 309, 1, 0, 0
    ],
    "DE 25 A 30 AÑOS": [
        12, 1108, 161, 12, 437, 2168, 246, 243, 150, 29, 100, 110, 532, 34, 125, 444, 0, 9, 162, 55, 269, 132, 206, 52,
        186, 13, 133, 177, 504, 34, 122, 807, 15, 1, 1
    ],
    "DE 31 A 40 AÑOS": [
        18, 1897, 255, 21, 926, 3809, 601, 375, 305, 44, 201, 233, 934, 104, 184, 809, 0, 16, 358, 107, 504, 275, 358,
        151, 337, 22, 283, 275, 972, 69, 280, 1542, 21, 1, 0
    ],
    "DE 41 A 55 AÑOS": [
        11, 1670, 215, 12, 875, 3679, 522, 374, 256, 46, 229, 217, 988, 103, 173, 802, 1, 9, 304, 91, 490, 263, 351, 121,
        296, 14, 245, 282, 719, 43, 260, 1462, 9, 2, 1
    ],
    "DE 56 AÑOS Y MAYOR": [
        4, 315, 53, 8, 195, 820, 97, 73, 53, 13, 49, 51, 263, 26, 56, 158, 1, 1, 73, 12, 149, 71, 96, 23, 79, 0, 48, 53,
        150, 7, 55, 327, 3, 0, 0
    ]
}

# Crear el DataFrame
df = pd.DataFrame(data)

# Reorganizar el dataframe en formato largo
df_melted = df.melt(id_vars='Departamento',
                    var_name='Rango de Edad',
                    value_name='Cantidad')

# Definir el orden lógico de los rangos de edad
orden_edades = [
    'DE 17 AÑOS Y MENOR',
    'DE 18 A 24 AÑOS',
    'DE 25 A 30 AÑOS',
    'DE 31 A 40 AÑOS',
    'DE 41 A 55 AÑOS',
    'DE 56 AÑOS Y MAYOR'
]

# Crear gráfico
plt.figure(figsize=(18, 10))
sns.set(style="whitegrid")
palette = sns.color_palette("dark", n_colors=len(orden_edades))

barplot = sns.barplot(
    data=df_melted,
    x='Departamento',
    y='Cantidad',
    hue='Rango de Edad',
    hue_order=orden_edades,
    palette=palette
)

# Estilo de la gráfica
plt.title('Distribución Poblacional por Departamento y Rango de Edad', fontsize=20, weight='bold')
plt.xlabel('Departamento', fontsize=12)
plt.ylabel('Cantidad de Personas', fontsize=12)
plt.xticks(rotation=90)
plt.legend(title='Rango de Edad', bbox_to_anchor=(1.02, 1), loc='upper left')
plt.tight_layout()

# Mostrar la gráfica
plt.show()
