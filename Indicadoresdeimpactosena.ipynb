# %% [markdown]
# <a href="https://colab.research.google.com/github/richbello/sena_ggpc/blob/main/Indicadoresdeimpactosena.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# Abre el cuadro de diálogo para subir archivos
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3e6e97e5-4436-4ac6-b853-3eaf9c5e93d3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3e6e97e5-4436-4ac6-b853-3eaf9c5e93d3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Reemplaza con el nombre exacto del archivo subido
archivo = 'INDICADORES DE IMPACTO DILIGENCIADO JUAN MA_solo matriz.xlsx'

# Cargar los datos desde el Excel
df = pd.read_excel(archivo)

# Ver las primeras filas
df.head()
# Out:
#    ITEM                  EMPRESA                         INDICADOR  \
# 0   1.0  UNIÓN TEMPORAL KERALTY   Mejoramiento en la empleabilidad
# 1   2.0  UNIÓN TEMPORAL KERALTY      Retención de los trabajadores
# 2   3.0  UNIÓN TEMPORAL KERALTY                  Movilidad laboral
# 3   4.0  UNIÓN TEMPORAL KERALTY             Empresas beneficiarias
# 4   5.0  UNIÓN TEMPORAL KERALTY         Trabajadores beneficiarios
#
#                                      ASPECTO A MEDIR  \
# 0  Mide cómo se mejoran las condiciones económica...
# 1  Mide la retención de los trabajadores benefici...
# 2  Mide la movilidad de los trabajadores benefici...
# 3  Mide el porcentaje de las empresas beneficiari...
# 4  Mide el porcentaje de trabajadores beneficiari...
#
#                                 VARIABLE INDICADOR 1  \
# 0  Número de trabajadores beneficiarios con incre...
# 1  Número de trabajadores beneficiarios que conti...
# 2  Número de trabajadores beneficiarios que cambi...
# ...

# %%
df.columns.tolist()
# Out:
# ['ITEM',
#  'EMPRESA',
#  'INDICADOR',
#  'ASPECTO A MEDIR',
#  'VARIABLE INDICADOR 1',
#  'VARIABLE INDICADOR 2',
#  'VARIABLE CUANTITATIVA E1',
#  'VARIABLE CUANTITATIVA E2',
#  'META (%)\nSituación esperada',
#  'META (%)  AL FINALIZAR LA EJECUCION\nSituación esperada',
#  'VARIABLE CUANTITATIVA M1',
#  'VARIABLE CUANTITATIVA M2',
#  'ANALISIS DEL RESULTADO']

# %%
# Importar librerías necesarias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Leer el archivo (ya subido)
archivo = 'INDICADORES DE IMPACTO DILIGENCIADO JUAN MA_solo matriz.xlsx'
df = pd.read_excel(archivo)

# Seleccionar y limpiar columnas relevantes
df_limpio = df[['VARIABLE INDICADOR 1', 'VARIABLE CUANTITATIVA E1', 'VARIABLE CUANTITATIVA M1']].copy()
df_limpio.columns = ['Indicador', 'Valor_E1', 'Valor_M1']

# Eliminar filas vacías o con valores faltantes en los campos clave
df_limpio.dropna(subset=['Indicador', 'Valor_E1', 'Valor_M1'], inplace=True)

# Crear gráfico de barras comparando valores
plt.figure(figsize=(12, 6))
df_limpio_melted = pd.melt(df_limpio, id_vars='Indicador', var_name='Tipo', value_name='Valor')

# Crear el gráfico
sns.barplot(data=df_limpio_melted, x='Indicador', y='Valor', hue='Tipo', palette='Set2')

# Ajustes visuales
plt.title('Comparación de Indicadores: Valor E1 vs M1', fontsize=16)
plt.ylabel('Cantidad')
plt.xlabel('Indicador')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()

# Mostrar gráfico
plt.show()
# Out:
# /tmp/ipython-input-6-3107663846.py:30: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
